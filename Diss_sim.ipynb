# %%
import itertools


# Value encoding through the use of natural bases
def value_encoding(val):
    mapping = {"1": "A", "2": "T"}
    sequence = ''
    for k in sorted(mapping.keys(), key=int, reverse=True):
        while val >= int(k):
            sequence += mapping[k]
            val -= int(k)
    return sequence

# Weight encoding through the use of synthetic bases
def weight_encoding(wt):
    mapping = {"1": "P", "2": "Z", "4": "B", "8": "S"}
    sequence = ''
    for k in sorted(mapping.keys(), key=int, reverse=True):
        while wt >= int(k):
            sequence += mapping[k]
            wt -= int(k)
    return sequence

def summation(weight, value):
    return value_encoding(value) + weight_encoding(weight)

# Complementary bases based on Watson-Crick priciple
def gen_complement(seq):
    complements = {"A": "T", "T": "A", "G": "C", "C": "G", "P": "Z", "Z": "P", "B": "S", "S": "B"}
    return "".join(complements[char] for char in seq)

def gen_linker(seq1, seq2):
    end_of_seq1 = seq1[-3:]
    start_of_seq2 = seq2[:3]
    return gen_complement(end_of_seq1) + gen_complement(start_of_seq2)

# Formulation of problem presented in the report
items = [
    {"weight": 15, "value": 7},
    {"weight": 36, "value": 10},
    {"weight": 30, "value": 12},
    {"weight": 18, "value": 8},
    {"weight": 21, "value": 11},
    {"weight": 24, "value": 10},
]

# Initial encoding of items in single stranded sequences
print("Initial Item Sequences:\n")
for i, item in enumerate(items, 1):
    sequence = summation(item["weight"], item["value"])
    linker = gen_complement(sequence[:3]) + gen_complement(sequence[-3:])
    central = sequence[3:-3]
    reverse_central_complement = gen_complement(central)
    print(f"Item {i}: {sequence}")
    print(f"Linker for Item {i}: {linker}")
    print(f"Item {i} with reverse central complement:")
    print(sequence[:3] + central + sequence[-3:])
    print("   " + reverse_central_complement + "\n")

# Hybridised double stranded sequences
print("\nHybridised Double Stranded Sequences:\n")
for i in range(len(items)):
    for j in range(i+1, len(items)):
        seq1 = summation(items[i]["weight"], items[i]["value"])
        seq2 = summation(items[j]["weight"], items[j]["value"])
        linker = gen_linker(seq1, seq2)
        combined_seq = seq1 + seq2
        combined_comp = gen_complement(combined_seq)
        print(f"Hybridised double stranded sequence of Item {i+1} and Item {j+1}:")
        print(combined_seq)
        print(combined_comp + "\n")

# Melted single stranded sequences
print("\nMelted Single Stranded Sequences:\n")
for r in range(2, 7):
    for combination in itertools.combinations(range(6), r):
        combined_seq = ''.join(summation(items[idx]["weight"], items[idx]["value"]) for idx in combination)
        combination_names = " and ".join(f"Item {idx+1}" for idx in combination)
        print(f"Single stranded sequence of {combination_names}: {combined_seq}\n")

knapsack_weight_constraint = 90
filtered_combinations = []

# Filtered strands
print("\nSingle Stranded Sequences Obeying the Knapsack Weight Constraint:\n")
for r in range(2, 7):
    for combination in itertools.combinations(range(6), r):
        combined_weight = sum(items[idx]["weight"] for idx in combination)
        combined_value = sum(items[idx]["value"] for idx in combination)

        if combined_weight <= knapsack_weight_constraint:
            combined_seq = ''.join(summation(items[idx]["weight"], items[idx]["value"]) for idx in combination)
            combination_names = " and ".join(f"Item {idx+1}" for idx in combination)
            filtered_combinations.append({"sequence": combined_seq, "names": combination_names, "weight": combined_weight, "value": combined_value})
            print(f"Single stranded sequence of {combination_names}: {combined_seq} (Weight: {combined_weight})\n")

# Displaying the highest value strand
max_value_combination = max(filtered_combinations, key=lambda x: x["value"])
print("\nSingle Stranded Sequence with Largest Value Obeying the Knapsack Weight Constraint:")
print(f"Sequence: {max_value_combination['names']}")
print(f"Sequence: {max_value_combination['sequence']}")
print(f"Weight: {max_value_combination['weight']}")
print(f"Value: {max_value_combination['value']}\n")
# Out:
# Initial Item Sequences:
#
# Item 1: TTTASBZP
# Linker for Item 1: AAASPZ
# Item 1 with reverse central complement:
# TTTASBZP
#    TB
#
# Item 2: TTTTTSSSSB
# Linker for Item 2: AAABBS
# Item 2 with reverse central complement:
# TTTTTSSSSB
#    AABB
#
# Item 3: TTTTTTSSSBZ
# Linker for Item 3: AAABSP
# Item 3 with reverse central complement:
# TTTTTTSSSBZ
#    AAABB
#
# Item 4: TTTTSSZ
# Linker for Item 4: AAABBP
# Item 4 with reverse central complement:
# TTTTSSZ
#    A
#
# Item 5: TTTTTASSBP
# Linker for Item 5: AAABSZ
# Item 5 with reverse central complement:
# TTTTTASSBP
#    AATB
#
# Item 6: TTTTTSSS
# Linker for Item 6: AAABBB
# Item 6 with reverse central complement:
# TTTTTSSS
#    AA
#
#
# Hybridised Double Stranded Sequences:
#
# Hybridised double stranded sequence of Item 1 and Item 2:
# TTTASBZPTTTTTSSSSB
# AAATBSPZAAAAABBBBS
#
# Hybridised double stranded sequence of Item 1 and Item 3:
# TTTASBZPTTTTTTSSSBZ
# AAATBSPZAAAAAABBBSP
#
# Hybridised double stranded sequence of Item 1 and Item 4:
# TTTASBZPTTTTSSZ
# AAATBSPZAAAABBP
#
# Hybridised double stranded sequence of Item 1 and Item 5:
# TTTASBZPTTTTTASSBP
# AAATBSPZAAAAATBBSZ
#
# Hybridised double stranded sequence of Item 1 and Item 6:
# TTTASBZPTTTTTSSS
# AAATBSPZAAAAABBB
#
# Hybridised double stranded sequence of Item 2 and Item 3:
# TTTTTSSSSBTTTTTTSSSBZ
# AAAAABBBBSAAAAAABBBSP
#
# Hybridised double stranded sequence of Item 2 and Item 4:
# TTTTTSSSSBTTTTSSZ
# AAAAABBBBSAAAABBP
#
# Hybridised double stranded sequence of Item 2 and Item 5:
# TTTTTSSSSBTTTTTASSBP
# AAAAABBBBSAAAAATBBSZ
#
# Hybridised double stranded sequence of Item 2 and Item 6:
# TTTTTSSSSBTTTTTSSS
# AAAAABBBBSAAAAABBB
#
# Hybridised double stranded sequence of Item 3 and Item 4:
# TTTTTTSSSBZTTTTSSZ
# AAAAAABBBSPAAAABBP
#
# Hybridised double stranded sequence of Item 3 and Item 5:
# TTTTTTSSSBZTTTTTASSBP
# AAAAAABBBSPAAAAATBBSZ
#
# Hybridised double stranded sequence of Item 3 and Item 6:
# TTTTTTSSSBZTTTTTSSS
# AAAAAABBBSPAAAAABBB
#
# Hybridised double stranded sequence of Item 4 and Item 5:
# TTTTSSZTTTTTASSBP
# AAAABBPAAAAATBBSZ
#
# Hybridised double stranded sequence of Item 4 and Item 6:
# TTTTSSZTTTTTSSS
# AAAABBPAAAAABBB
#
# Hybridised double stranded sequence of Item 5 and Item 6:
# TTTTTASSBPTTTTTSSS
# AAAAATBBSZAAAAABBB
#
#
# Melted Single Stranded Sequences:
#
# Single stranded sequence of Item 1 and Item 2: TTTASBZPTTTTTSSSSB
#
# Single stranded sequence of Item 1 and Item 3: TTTASBZPTTTTTTSSSBZ
#
# Single stranded sequence of Item 1 and Item 4: TTTASBZPTTTTSSZ
#
# Single stranded sequence of Item 1 and Item 5: TTTASBZPTTTTTASSBP
#
# Single stranded sequence of Item 1 and Item 6: TTTASBZPTTTTTSSS
#
# Single stranded sequence of Item 2 and Item 3: TTTTTSSSSBTTTTTTSSSBZ
#
# Single stranded sequence of Item 2 and Item 4: TTTTTSSSSBTTTTSSZ
#
# Single stranded sequence of Item 2 and Item 5: TTTTTSSSSBTTTTTASSBP
#
# Single stranded sequence of Item 2 and Item 6: TTTTTSSSSBTTTTTSSS
#
# Single stranded sequence of Item 3 and Item 4: TTTTTTSSSBZTTTTSSZ
#
# Single stranded sequence of Item 3 and Item 5: TTTTTTSSSBZTTTTTASSBP
#
# Single stranded sequence of Item 3 and Item 6: TTTTTTSSSBZTTTTTSSS
#
# Single stranded sequence of Item 4 and Item 5: TTTTSSZTTTTTASSBP
#
# Single stranded sequence of Item 4 and Item 6: TTTTSSZTTTTTSSS
#
# Single stranded sequence of Item 5 and Item 6: TTTTTASSBPTTTTTSSS
#
# Single stranded sequence of Item 1 and Item 2 and Item 3: TTTASBZPTTTTTSSSSBTTTTTTSSSBZ
#
# Single stranded sequence of Item 1 and Item 2 and Item 4: TTTASBZPTTTTTSSSSBTTTTSSZ
#
# Single stranded sequence of Item 1 and Item 2 and Item 5: TTTASBZPTTTTTSSSSBTTTTTASSBP
#
# Single stranded sequence of Item 1 and Item 2 and Item 6: TTTASBZPTTTTTSSSSBTTTTTSSS
#
# Single stranded sequence of Item 1 and Item 3 and Item 4: TTTASBZPTTTTTTSSSBZTTTTSSZ
#
# Single stranded sequence of Item 1 and Item 3 and Item 5: TTTASBZPTTTTTTSSSBZTTTTTASSBP
#
# Single stranded sequence of Item 1 and Item 3 and Item 6: TTTASBZPTTTTTTSSSBZTTTTTSSS
#
# Single stranded sequence of Item 1 and Item 4 and Item 5: TTTASBZPTTTTSSZTTTTTASSBP
#
# Single stranded sequence of Item 1 and Item 4 and Item 6: TTTASBZPTTTTSSZTTTTTSSS
#
# Single stranded sequence of Item 1 and Item 5 and Item 6: TTTASBZPTTTTTASSBPTTTTTSSS
#
# Single stranded sequence of Item 2 and Item 3 and Item 4: TTTTTSSSSBTTTTTTSSSBZTTTTSSZ
#
# Single stranded sequence of Item 2 and Item 3 and Item 5: TTTTTSSSSBTTTTTTSSSBZTTTTTASSBP
#
# Single stranded sequence of Item 2 and Item 3 and Item 6: TTTTTSSSSBTTTTTTSSSBZTTTTTSSS
#
# Single stranded sequence of Item 2 and Item 4 and Item 5: TTTTTSSSSBTTTTSSZTTTTTASSBP
#
# Single stranded sequence of Item 2 and Item 4 and Item 6: TTTTTSSSSBTTTTSSZTTTTTSSS
#
# Single stranded sequence of Item 2 and Item 5 and Item 6: TTTTTSSSSBTTTTTASSBPTTTTTSSS
#
# Single stranded sequence of Item 3 and Item 4 and Item 5: TTTTTTSSSBZTTTTSSZTTTTTASSBP
#
# Single stranded sequence of Item 3 and Item 4 and Item 6: TTTTTTSSSBZTTTTSSZTTTTTSSS
#
# Single stranded sequence of Item 3 and Item 5 and Item 6: TTTTTTSSSBZTTTTTASSBPTTTTTSSS
#
# Single stranded sequence of Item 4 and Item 5 and Item 6: TTTTSSZTTTTTASSBPTTTTTSSS
#
# Single stranded sequence of Item 1 and Item 2 and Item 3 and Item 4: TTTASBZPTTTTTSSSSBTTTTTTSSSBZTTTTSSZ
#
# Single stranded sequence of Item 1 and Item 2 and Item 3 and Item 5: TTTASBZPTTTTTSSSSBTTTTTTSSSBZTTTTTASSBP
#
# Single stranded sequence of Item 1 and Item 2 and Item 3 and Item 6: TTTASBZPTTTTTSSSSBTTTTTTSSSBZTTTTTSSS
#
# Single stranded sequence of Item 1 and Item 2 and Item 4 and Item 5: TTTASBZPTTTTTSSSSBTTTTSSZTTTTTASSBP
#
# Single stranded sequence of Item 1 and Item 2 and Item 4 and Item 6: TTTASBZPTTTTTSSSSBTTTTSSZTTTTTSSS
#
# Single stranded sequence of Item 1 and Item 2 and Item 5 and Item 6: TTTASBZPTTTTTSSSSBTTTTTASSBPTTTTTSSS
#
# Single stranded sequence of Item 1 and Item 3 and Item 4 and Item 5: TTTASBZPTTTTTTSSSBZTTTTSSZTTTTTASSBP
#
# Single stranded sequence of Item 1 and Item 3 and Item 4 and Item 6: TTTASBZPTTTTTTSSSBZTTTTSSZTTTTTSSS
#
# Single stranded sequence of Item 1 and Item 3 and Item 5 and Item 6: TTTASBZPTTTTTTSSSBZTTTTTASSBPTTTTTSSS
#
# Single stranded sequence of Item 1 and Item 4 and Item 5 and Item 6: TTTASBZPTTTTSSZTTTTTASSBPTTTTTSSS
#
# Single stranded sequence of Item 2 and Item 3 and Item 4 and Item 5: TTTTTSSSSBTTTTTTSSSBZTTTTSSZTTTTTASSBP
#
# Single stranded sequence of Item 2 and Item 3 and Item 4 and Item 6: TTTTTSSSSBTTTTTTSSSBZTTTTSSZTTTTTSSS
#
# Single stranded sequence of Item 2 and Item 3 and Item 5 and Item 6: TTTTTSSSSBTTTTTTSSSBZTTTTTASSBPTTTTTSSS
#
# Single stranded sequence of Item 2 and Item 4 and Item 5 and Item 6: TTTTTSSSSBTTTTSSZTTTTTASSBPTTTTTSSS
#
# Single stranded sequence of Item 3 and Item 4 and Item 5 and Item 6: TTTTTTSSSBZTTTTSSZTTTTTASSBPTTTTTSSS
#
# Single stranded sequence of Item 1 and Item 2 and Item 3 and Item 4 and Item 5: TTTASBZPTTTTTSSSSBTTTTTTSSSBZTTTTSSZTTTTTASSBP
#
# Single stranded sequence of Item 1 and Item 2 and Item 3 and Item 4 and Item 6: TTTASBZPTTTTTSSSSBTTTTTTSSSBZTTTTSSZTTTTTSSS
#
# Single stranded sequence of Item 1 and Item 2 and Item 3 and Item 5 and Item 6: TTTASBZPTTTTTSSSSBTTTTTTSSSBZTTTTTASSBPTTTTTSSS
#
# Single stranded sequence of Item 1 and Item 2 and Item 4 and Item 5 and Item 6: TTTASBZPTTTTTSSSSBTTTTSSZTTTTTASSBPTTTTTSSS
#
# Single stranded sequence of Item 1 and Item 3 and Item 4 and Item 5 and Item 6: TTTASBZPTTTTTTSSSBZTTTTSSZTTTTTASSBPTTTTTSSS
#
# Single stranded sequence of Item 2 and Item 3 and Item 4 and Item 5 and Item 6: TTTTTSSSSBTTTTTTSSSBZTTTTSSZTTTTTASSBPTTTTTSSS
#
# Single stranded sequence of Item 1 and Item 2 and Item 3 and Item 4 and Item 5 and Item 6: TTTASBZPTTTTTSSSSBTTTTTTSSSBZTTTTSSZTTTTTASSBPTTTTTSSS
#
#
# Single Stranded Sequences Obeying the Knapsack Weight Constraint:
#
# Single stranded sequence of Item 1 and Item 2: TTTASBZPTTTTTSSSSB (Weight: 51)
#
# Single stranded sequence of Item 1 and Item 3: TTTASBZPTTTTTTSSSBZ (Weight: 45)
#
# Single stranded sequence of Item 1 and Item 4: TTTASBZPTTTTSSZ (Weight: 33)
#
# Single stranded sequence of Item 1 and Item 5: TTTASBZPTTTTTASSBP (Weight: 36)
#
# Single stranded sequence of Item 1 and Item 6: TTTASBZPTTTTTSSS (Weight: 39)
#
# Single stranded sequence of Item 2 and Item 3: TTTTTSSSSBTTTTTTSSSBZ (Weight: 66)
#
# Single stranded sequence of Item 2 and Item 4: TTTTTSSSSBTTTTSSZ (Weight: 54)
#
# Single stranded sequence of Item 2 and Item 5: TTTTTSSSSBTTTTTASSBP (Weight: 57)
#
# Single stranded sequence of Item 2 and Item 6: TTTTTSSSSBTTTTTSSS (Weight: 60)
#
# Single stranded sequence of Item 3 and Item 4: TTTTTTSSSBZTTTTSSZ (Weight: 48)
#
# Single stranded sequence of Item 3 and Item 5: TTTTTTSSSBZTTTTTASSBP (Weight: 51)
#
# Single stranded sequence of Item 3 and Item 6: TTTTTTSSSBZTTTTTSSS (Weight: 54)
#
# Single stranded sequence of Item 4 and Item 5: TTTTSSZTTTTTASSBP (Weight: 39)
#
# Single stranded sequence of Item 4 and Item 6: TTTTSSZTTTTTSSS (Weight: 42)
#
# Single stranded sequence of Item 5 and Item 6: TTTTTASSBPTTTTTSSS (Weight: 45)
#
# Single stranded sequence of Item 1 and Item 2 and Item 3: TTTASBZPTTTTTSSSSBTTTTTTSSSBZ (Weight: 81)
#
# Single stranded sequence of Item 1 and Item 2 and Item 4: TTTASBZPTTTTTSSSSBTTTTSSZ (Weight: 69)
#
# Single stranded sequence of Item 1 and Item 2 and Item 5: TTTASBZPTTTTTSSSSBTTTTTASSBP (Weight: 72)
#
# Single stranded sequence of Item 1 and Item 2 and Item 6: TTTASBZPTTTTTSSSSBTTTTTSSS (Weight: 75)
#
# Single stranded sequence of Item 1 and Item 3 and Item 4: TTTASBZPTTTTTTSSSBZTTTTSSZ (Weight: 63)
#
# Single stranded sequence of Item 1 and Item 3 and Item 5: TTTASBZPTTTTTTSSSBZTTTTTASSBP (Weight: 66)
#
# Single stranded sequence of Item 1 and Item 3 and Item 6: TTTASBZPTTTTTTSSSBZTTTTTSSS (Weight: 69)
#
# Single stranded sequence of Item 1 and Item 4 and Item 5: TTTASBZPTTTTSSZTTTTTASSBP (Weight: 54)
#
# Single stranded sequence of Item 1 and Item 4 and Item 6: TTTASBZPTTTTSSZTTTTTSSS (Weight: 57)
#
# Single stranded sequence of Item 1 and Item 5 and Item 6: TTTASBZPTTTTTASSBPTTTTTSSS (Weight: 60)
#
# Single stranded sequence of Item 2 and Item 3 and Item 4: TTTTTSSSSBTTTTTTSSSBZTTTTSSZ (Weight: 84)
#
# Single stranded sequence of Item 2 and Item 3 and Item 5: TTTTTSSSSBTTTTTTSSSBZTTTTTASSBP (Weight: 87)
#
# Single stranded sequence of Item 2 and Item 3 and Item 6: TTTTTSSSSBTTTTTTSSSBZTTTTTSSS (Weight: 90)
#
# Single stranded sequence of Item 2 and Item 4 and Item 5: TTTTTSSSSBTTTTSSZTTTTTASSBP (Weight: 75)
#
# Single stranded sequence of Item 2 and Item 4 and Item 6: TTTTTSSSSBTTTTSSZTTTTTSSS (Weight: 78)
#
# Single stranded sequence of Item 2 and Item 5 and Item 6: TTTTTSSSSBTTTTTASSBPTTTTTSSS (Weight: 81)
#
# Single stranded sequence of Item 3 and Item 4 and Item 5: TTTTTTSSSBZTTTTSSZTTTTTASSBP (Weight: 69)
#
# Single stranded sequence of Item 3 and Item 4 and Item 6: TTTTTTSSSBZTTTTSSZTTTTTSSS (Weight: 72)
#
# Single stranded sequence of Item 3 and Item 5 and Item 6: TTTTTTSSSBZTTTTTASSBPTTTTTSSS (Weight: 75)
#
# Single stranded sequence of Item 4 and Item 5 and Item 6: TTTTSSZTTTTTASSBPTTTTTSSS (Weight: 63)
#
# Single stranded sequence of Item 1 and Item 2 and Item 4 and Item 5: TTTASBZPTTTTTSSSSBTTTTSSZTTTTTASSBP (Weight: 90)
#
# Single stranded sequence of Item 1 and Item 3 and Item 4 and Item 5: TTTASBZPTTTTTTSSSBZTTTTSSZTTTTTASSBP (Weight: 84)
#
# Single stranded sequence of Item 1 and Item 3 and Item 4 and Item 6: TTTASBZPTTTTTTSSSBZTTTTSSZTTTTTSSS (Weight: 87)
#
# Single stranded sequence of Item 1 and Item 3 and Item 5 and Item 6: TTTASBZPTTTTTTSSSBZTTTTTASSBPTTTTTSSS (Weight: 90)
#
# Single stranded sequence of Item 1 and Item 4 and Item 5 and Item 6: TTTASBZPTTTTSSZTTTTTASSBPTTTTTSSS (Weight: 78)
#
#
# Single Stranded Sequence with Largest Value Obeying the Knapsack Weight Constraint:
# Sequence: Item 1 and Item 3 and Item 5 and Item 6
# Sequence: TTTASBZPTTTTTTSSSBZTTTTTASSBPTTTTTSSS
# Weight: 90
# Value: 40
